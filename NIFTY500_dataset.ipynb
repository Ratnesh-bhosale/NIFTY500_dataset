# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 63 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 6.4 MB 12.0 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf
yf.pdr_override()

import warnings
warnings.filterwarnings("ignore")

# %%
tickers = pd.read_excel('/content/MCAP_31032020_TOP500.xlsx', index_col=0)

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
tickers.head()
# Out:
#              Symbol                                     Company Name  \
# Sr. No.
# 1          RELIANCE                      Reliance Industries Limited
# 2               TCS                Tata Consultancy Services Limited
# 3        HINDUNILVR                       Hindustan Unilever Limited
# 4          HDFCBANK                                HDFC Bank Limited
# 5              HDFC  Housing Development Finance Corporation Limited
#
#          Market Capitalisation \n(In lakhs)
# Sr. No.
# 1                              7.060358e+07
# 2                              6.852230e+07
# 3                              4.975841e+07
# 4                              4.724823e+07
# 5                              2.823571e+07

# %%
# input
start = '2012-01-01' 
end = '2022-01-01'

# %%
print("Parsing Started....")
count=0
for i in tickers.Symbol:
  symbol = i+ '.NS'
  df = yf.download(symbol,start,end)
  df.to_csv("/content/drive/MyDrive/Dataset - Stock NIFTY100/"+str(count)+ "_" + i +'.csv')
  #!cp data.csv "/content/drive/MyDrive/Dataset - Stock NIFTY100"
  print("Done ", count, " ", symbol)
  count+=1

  # if count==3:
  #   break
  print("PARSED!")
# Out:
# Parsing Started....
# [*********************100%***********************]  1 of 1 completed
# Done  0   RELIANCE.NS
# PARSED!
# [*********************100%***********************]  1 of 1 completed
# Done  1   TCS.NS
# PARSED!
# [*********************100%***********************]  1 of 1 completed
# Done  2   HINDUNILVR.NS
# PARSED!
# [*********************100%***********************]  1 of 1 completed
# Done  3   HDFCBANK.NS
# PARSED!
# [*********************100%***********************]  1 of 1 completed
# Done  4   HDFC.NS
# PARSED!
# [*********************100%***********************]  1 of 1 completed
# Done  5   INFY.NS
# PARSED!
# [*********************100%***********************]  1 of 1 completed
# Done  6   KOTAKBANK.NS
# PARSED!
# [*********************100%***********************]  1 of 1 completed
# Done  7   BHARTIARTL.NS
# PARSED!
# [*********************100%***********************]  1 of 1 completed
# Done  8   ITC.NS
# PARSED!
# ...
